# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import re
import os
import glob
from google.colab import drive

# Montar Google Drive (para Colab)
drive.mount('/content/drive')

def buscar_imdb(titulo_pelicula, año_pelicula):
    """
    Busca una película en IMDB por título y año
    """
    cabeceras = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    url_busqueda = f"https://www.imdb.com/find/?q={titulo_pelicula.replace(' ', '+')}&s=tt"

    print(f"Buscando en IMDB: {titulo_pelicula} ({año_pelicula})")

    try:
        respuesta = requests.get(url_busqueda, headers=cabeceras)
        if respuesta.status_code != 200:
            print(f"Error al buscar en IMDB: Código {respuesta.status_code}")
            return None

        sopa = BeautifulSoup(respuesta.text, 'html.parser')

        # Buscar enlaces de títulos
        resultados = sopa.select('li.ipc-metadata-list-summary-item a[href^="/title/tt"]')

        for enlace in resultados:
            texto_titulo = enlace.get_text(strip=True)
            href = enlace['href']

            # Extraer año si está presente
            li_padre = enlace.find_parent('li')
            coincidencia_año = re.search(r'\d{4}', li_padre.get_text() if li_padre else '')
            año_encontrado = int(coincidencia_año.group()) if coincidencia_año else None

            # Validar coincidencia del año
            if año_encontrado and abs(año_encontrado - int(año_pelicula)) <= 1:
                return f"https://www.imdb.com{href}"

        print(f"No se encontró una coincidencia exacta para {titulo_pelicula} ({año_pelicula})")
        return None

    except Exception as e:
        print(f"Error al buscar en IMDB: {str(e)}")
        return None


def obtener_puntuacion_imdb(url_imdb):
    """
    Extrae la puntuación de IMDB de la página de una película
    """
    cabeceras = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    print(f"Extrayendo puntuación de IMDB: {url_imdb}")

    try:
        respuesta = requests.get(url_imdb, headers=cabeceras)

        if respuesta.status_code != 200:
            print(f"Error al acceder a {url_imdb}: Código {respuesta.status_code}")
            return None, None

        sopa = BeautifulSoup(respuesta.text, 'html.parser')

        # Buscar puntuación en elementos específicos
        elemento_puntuacion = sopa.select_one('[data-testid="hero-rating-bar__aggregate-rating__score"] span')
        elemento_votos = sopa.select_one('.sc-d541859f-3')

        if elemento_puntuacion:
            puntuacion = elemento_puntuacion.text.strip()
            try:
                puntuacion = float(puntuacion)
            except ValueError:
                puntuacion = None
        else:
            puntuacion = None


        if elemento_votos:
            texto_votos = elemento_votos.text.strip()

            # Convertir votos tipo "224K", "1.2M", etc. a número real
            multiplicador = 1
            if 'K' in texto_votos.upper():
                multiplicador = 1_000
                texto_votos = texto_votos.upper().replace('K', '')
            elif 'M' in texto_votos.upper():
                multiplicador = 1_000_000
                texto_votos = texto_votos.upper().replace('M', '')

            try:
                votos = int(float(texto_votos) * multiplicador)
            except ValueError:
                votos = None
        else:
            votos = None

        if not votos:
            coincidencia_votos = re.search(r'"aggregateRating":.*?"ratingCount":\s*(\d+)', respuesta.text)
            if coincidencia_votos:
                try:
                    votos = int(coincidencia_votos.group(1))
                except ValueError:
                    pass

        return puntuacion, votos

    except Exception as e:
        print(f"Error al extraer puntuación de IMDB: {str(e)}")
        return None, None

def añadir_puntuaciones_imdb_a_excel(ruta_archivo_entrada, ruta_archivo_salida):
    """
    Lee un archivo Excel, busca las películas en IMDB y añade las puntuaciones
    """
    try:
        # Comprobar si el archivo existe
        if not os.path.exists(ruta_archivo_entrada):
            print(f"El archivo {ruta_archivo_entrada} no existe")
            return False

        # Leer el archivo Excel
        print(f"Leyendo archivo Excel: {ruta_archivo_entrada}")
        df = pd.read_excel(ruta_archivo_entrada)

        # Verificar que el DataFrame tiene datos
        if df.empty:
            print("El archivo Excel no contiene datos")
            return False

        print(f"Se han encontrado {len(df)} películas en el Excel")

        # Añadir columnas para puntuación de IMDB y votos
        df['imdb_url'] = None
        df['imdb_puntuacion'] = None
        df['imdb_votos'] = None

        # Para cada película, buscar en IMDB y obtener puntuación
        for indice, fila in df.iterrows():
            titulo = fila['titulo_original']
            año = fila['anio']

            print(f"\nProcesando película {indice+1}/{len(df)}: {titulo} ({año})")

            # Buscar la película en IMDB
            url_imdb = buscar_imdb(titulo, año)

            if url_imdb:
                # Obtener puntuación de IMDB
                puntuacion_imdb, votos_imdb = obtener_puntuacion_imdb(url_imdb)

                # Actualizar DataFrame
                df.at[indice, 'imdb_url'] = url_imdb
                df.at[indice, 'imdb_puntuacion'] = puntuacion_imdb
                df.at[indice, 'imdb_votos'] = votos_imdb

                print(f"Puntuación IMDB para {titulo}: {puntuacion_imdb} ({votos_imdb} votos)")
            else:
                print(f"No se encontró la película en IMDB: {titulo}")

            # Pausa para evitar sobrecarga
            time.sleep(random.uniform(2, 5))

        # Guardar el resultado final
        df.to_excel(ruta_archivo_salida, index=False)
        ruta_csv = ruta_archivo_salida.replace('.xlsx', '.csv')
        df.to_csv(ruta_csv, sep=';', index=False, encoding='utf-8-sig')
        print(f"Archivo CSV exportado a: {ruta_csv}")
        print(f"\nProceso completado. Archivo guardado en: {ruta_archivo_salida}")

        # Estadísticas
        contador_imdb = df['imdb_puntuacion'].count()
        print(f"Se encontraron puntuaciones de IMDB para {contador_imdb} de {len(df)} películas ({contador_imdb/len(df)*100:.1f}%)")

        if contador_imdb > 0:
            puntuacion_media = df['imdb_puntuacion'].mean()
            print(f"Puntuación media de IMDB: {puntuacion_media:.1f}")

        return True

    except Exception as e:
        print(f"Error al procesar el archivo Excel: {str(e)}")
        return False

def obtener_archivos_disponibles():
    """
    Obtiene la lista de archivos Excel disponibles en la carpeta de scraping
    """
    ruta_base = "/content/drive/My Drive/Tipología/PEC2/scraping/"

    # Buscar todos los archivos Excel que coincidan con el patrón de nombre de archivo
    patron = ruta_base + "peliculas_filmaffinity_*.xlsx"
    archivos = glob.glob(patron)

    # Excluir archivos que ya contengan "imdb" en el nombre
    archivos = [archivo for archivo in archivos if "imdb" not in archivo]

    return archivos

if __name__ == "__main__":
    # Obtener archivos disponibles
    archivos_disponibles = obtener_archivos_disponibles()

    if not archivos_disponibles:
        print("No se encontraron archivos de películas en la carpeta.")
        exit(1)

    print("=== AÑADIR PUNTUACIONES DE IMDB A EXCEL ===")
    print("Archivos disponibles:")

    for i, archivo in enumerate(archivos_disponibles, 1):
        # Extraer el nombre de archivo sin la ruta
        nombre_archivo = os.path.basename(archivo)

        # Intentar extraer el rango de años del nombre de archivo
        coincidencia = re.search(r'(\d{4})-(\d{4})', nombre_archivo)
        if coincidencia:
            anio_inicio, anio_fin = coincidencia.groups()
            print(f"{i}. {nombre_archivo} (Rango de años: {anio_inicio}-{anio_fin})")
        else:
            print(f"{i}. {nombre_archivo}")

    # Solicitar al usuario que seleccione un archivo
    seleccion = 0
    while seleccion < 1 or seleccion > len(archivos_disponibles):
        try:
            seleccion = int(input(f"\nSeleccione un archivo (1-{len(archivos_disponibles)}): "))
        except ValueError:
            print("Por favor, ingrese un número válido.")

    archivo_entrada = archivos_disponibles[seleccion - 1]

    # Generar el nombre del archivo de salida
    nombre_base = os.path.basename(archivo_entrada)
    nombre_sin_extension = os.path.splitext(nombre_base)[0]

    # Crear nombre para el archivo de salida
    if "prueba" in nombre_base:
        archivo_salida = f"/content/drive/My Drive/Tipología/PEC2/scraping/{nombre_sin_extension}_imdb_prueba.xlsx"
    else:
        archivo_salida = f"/content/drive/My Drive/Tipología/PEC2/scraping/{nombre_sin_extension}_imdb.xlsx"

    print(f"\nArchivo de entrada: {archivo_entrada}")
    print(f"Archivo de salida: {archivo_salida}")

    # Ejecutar el proceso
    añadir_puntuaciones_imdb_a_excel(archivo_entrada, archivo_salida)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# === AÑADIR PUNTUACIONES DE IMDB A EXCEL ===
# Archivos disponibles:
# 1. peliculas_filmaffinity_1980-1989.xlsx (Rango de años: 1980-1989)
# 2. peliculas_filmaffinity_1990-1999.xlsx (Rango de años: 1990-1999)
#
# Seleccione un archivo (1-2): 2
#
# Archivo de entrada: /content/drive/My Drive/Tipología/PEC2/scraping/peliculas_filmaffinity_1990-1999.xlsx
# Archivo de salida: /content/drive/My Drive/Tipología/PEC2/scraping/peliculas_filmaffinity_1990-1999_imdb.xlsx
# Leyendo archivo Excel: /content/drive/My Drive/Tipología/PEC2/scraping/peliculas_filmaffinity_1990-1999.xlsx
# Se han encontrado 40 películas en el Excel
#
# Procesando película 1/40: Pretty Woman (1990)
# Buscando en IMDB: Pretty Woman (1990)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0100405/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Pretty Woman: 7.1 (384000 votos)
#
# Procesando película 2/40: Home Alone (1990)
# Buscando en IMDB: Home Alone (1990)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0099785/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Home Alone: 7.7 (694000 votos)
#
# Procesando película 3/40: Edward Scissorhands (1990)
# Buscando en IMDB: Edward Scissorhands (1990)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0099487/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Edward Scissorhands: 7.9 (545000 votos)
#
# Procesando película 4/40: Goodfellas (1990)
# Buscando en IMDB: Goodfellas (1990)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0099685/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Goodfellas: 8.7 (1300000 votos)
#
# Procesando película 5/40: The Silence of the Lambs (1991)
# Buscando en IMDB: The Silence of the Lambs (1991)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0102926/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para The Silence of the Lambs: 8.6 (1600000 votos)
#
# Procesando película 6/40: T2 - Terminator 2: Judgment Day (1991)
# Buscando en IMDB: T2 - Terminator 2: Judgment Day (1991)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt15187022/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para T2 - Terminator 2: Judgment Day: 6.0 (54 votos)
#
# Procesando película 7/40: Beauty and the Beast (1991)
# Buscando en IMDB: Beauty and the Beast (1991)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0101414/?ref_=fn_ttl_ttl_2
# Puntuación IMDB para Beauty and the Beast: 8.0 (492000 votos)
#
# Procesando película 8/40: Robin Hood: Prince of Thieves (1991)
# Buscando en IMDB: Robin Hood: Prince of Thieves (1991)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0102798/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Robin Hood: Prince of Thieves: 6.9 (215000 votos)
#
# Procesando película 9/40: Reservoir Dogs (1992)
# Buscando en IMDB: Reservoir Dogs (1992)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0105236/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Reservoir Dogs: 8.3 (1100000 votos)
#
# Procesando película 10/40: Aladdin (1992)
# Buscando en IMDB: Aladdin (1992)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0103639/?ref_=fn_ttl_ttl_2
# Puntuación IMDB para Aladdin: 8.0 (485000 votos)
#
# Procesando película 11/40: Unforgiven (1992)
# Buscando en IMDB: Unforgiven (1992)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0105695/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Unforgiven: 8.2 (453000 votos)
#
# Procesando película 12/40: Bram Stoker's Dracula (1992)
# Buscando en IMDB: Bram Stoker's Dracula (1992)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0103874/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Bram Stoker's Dracula: 7.4 (255000 votos)
#
# Procesando película 13/40: Schindler's List (1993)
# Buscando en IMDB: Schindler's List (1993)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0108052/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Schindler's List: 9.0 (1500000 votos)
#
# Procesando película 14/40: Jurassic Park (1993)
# Buscando en IMDB: Jurassic Park (1993)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0107290/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Jurassic Park: 8.2 (1100000 votos)
#
# Procesando película 15/40: The Nightmare Before Christmas (1993)
# Buscando en IMDB: The Nightmare Before Christmas (1993)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0107688/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para The Nightmare Before Christmas: 7.9 (394000 votos)
#
# Procesando película 16/40: Mrs. Doubtfire (1993)
# Buscando en IMDB: Mrs. Doubtfire (1993)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0107614/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Mrs. Doubtfire: 7.1 (303000 votos)
#
# Procesando película 17/40: Pulp Fiction (1994)
# Buscando en IMDB: Pulp Fiction (1994)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0110912/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Pulp Fiction: 8.9 (2300000 votos)
#
# Procesando película 18/40: Forrest Gump (1994)
# Buscando en IMDB: Forrest Gump (1994)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0109830/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Forrest Gump: 8.8 (2400000 votos)
#
# Procesando película 19/40: The Shawshank Redemption (1994)
# Buscando en IMDB: The Shawshank Redemption (1994)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0111161/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para The Shawshank Redemption: 9.3 (3000000 votos)
#
# Procesando película 20/40: The Lion King (1994)
# Buscando en IMDB: The Lion King (1994)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0110357/?ref_=fn_ttl_ttl_2
# Puntuación IMDB para The Lion King: 8.5 (1200000 votos)
#
# Procesando película 21/40: Seven (Se7en) (1995)
# Buscando en IMDB: Seven (Se7en) (1995)
# No se encontró una coincidencia exacta para Seven (Se7en) (1995)
# No se encontró la película en IMDB: Seven (Se7en)
#
# Procesando película 22/40: Toy Story (1995)
# Buscando en IMDB: Toy Story (1995)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0114709/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Toy Story: 8.3 (1100000 votos)
#
# Procesando película 23/40: Braveheart (1995)
# Buscando en IMDB: Braveheart (1995)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0112573/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Braveheart: 8.3 (1100000 votos)
#
# Procesando película 24/40: 12 Monkeys (1995)
# Buscando en IMDB: 12 Monkeys (1995)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0114746/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para 12 Monkeys: 8.0 (663000 votos)
#
# Procesando película 25/40: Trainspotting (1996)
# Buscando en IMDB: Trainspotting (1996)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0117951/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Trainspotting: 8.1 (747000 votos)
#
# Procesando película 26/40: Independence Day (1996)
# Buscando en IMDB: Independence Day (1996)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0116629/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Independence Day: 7.0 (625000 votos)
#
# Procesando película 27/40: Mission: Impossible (1996)
# Buscando en IMDB: Mission: Impossible (1996)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0117060/?ref_=fn_ttl_ttl_2
# Puntuación IMDB para Mission: Impossible: 7.2 (487000 votos)
#
# Procesando película 28/40: Fargo (1996)
# Buscando en IMDB: Fargo (1996)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0116282/?ref_=fn_ttl_ttl_2
# Puntuación IMDB para Fargo: 8.1 (753000 votos)
#
# Procesando película 29/40: La vita è bella (1997)
# Buscando en IMDB: La vita è bella (1997)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0118799/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para La vita è bella: 8.6 (775000 votos)
#
# Procesando película 30/40: Titanic (1997)
# Buscando en IMDB: Titanic (1997)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0120338/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Titanic: 7.9 (1300000 votos)
#
# Procesando película 31/40: Men in Black (MIB) (1997)
# Buscando en IMDB: Men in Black (MIB) (1997)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0119654/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Men in Black (MIB): 7.3 (637000 votos)
#
# Procesando película 32/40: As Good as It Gets (1997)
# Buscando en IMDB: As Good as It Gets (1997)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0119822/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para As Good as It Gets: 7.7 (328000 votos)
#
# Procesando película 33/40: There's Something About Mary (1998)
# Buscando en IMDB: There's Something About Mary (1998)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0129387/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para There's Something About Mary: 7.1 (338000 votos)
#
# Procesando película 34/40: American History X (1998)
# Buscando en IMDB: American History X (1998)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0120586/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para American History X: 8.5 (1200000 votos)
#
# Procesando película 35/40: Saving Private Ryan (1998)
# Buscando en IMDB: Saving Private Ryan (1998)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0120815/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Saving Private Ryan: 8.6 (1600000 votos)
#
# Procesando película 36/40: The Truman Show (1998)
# Buscando en IMDB: The Truman Show (1998)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0120382/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para The Truman Show: 8.2 (1300000 votos)
#
# Procesando película 37/40: The Matrix (1999)
# Buscando en IMDB: The Matrix (1999)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0133093/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para The Matrix: 8.7 (2100000 votos)
#
# Procesando película 38/40: Fight Club (1999)
# Buscando en IMDB: Fight Club (1999)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0137523/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para Fight Club: 8.8 (2500000 votos)
#
# Procesando película 39/40: American Beauty (1999)
# Buscando en IMDB: American Beauty (1999)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0169547/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para American Beauty: 8.3 (1200000 votos)
#
# Procesando película 40/40: The Sixth Sense (1999)
# Buscando en IMDB: The Sixth Sense (1999)
# Extrayendo puntuación de IMDB: https://www.imdb.com/title/tt0167404/?ref_=fn_ttl_ttl_1
# Puntuación IMDB para The Sixth Sense: 8.2 (1100000 votos)
# Archivo CSV exportado a: /content/drive/My Drive/Tipología/PEC2/scraping/peliculas_filmaffinity_1990-1999_imdb.csv
#
# Proceso completado. Archivo guardado en: /content/drive/My Drive/Tipología/PEC2/scraping/peliculas_filmaffinity_1990-1999_imdb.xlsx
# Se encontraron puntuaciones de IMDB para 39 de 40 películas (97.5%)
# Puntuación media de IMDB: 8.0
